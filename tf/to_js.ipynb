# %%
# !pip install tensorflowjs
# Out:
# ...
#      |████████████████████████████████| 61kB 3.4MB/s
# ...
#      |████████████████████████████████| 512kB 22.8MB/s
# ...
#      |████████████████████████████████| 256kB 51.7MB/s
# ...
#      |████████████████████████████████| 901kB 50.1MB/s
# ...
#      |████████████████████████████████| 686kB 62.7MB/s
# ...
#   Created wheel for PyInquirer: filename=PyInquirer-1.0.3-cp27-none-any.whl size=32852 sha256=f8d146cd5513d403e3858e7f858248863ea8af4bca194596d36e7d96f7ac955d
#   Stored in directory: /root/.cache/pip/wheels/52/6c/b1/3e4b0e8daf42a92883c7641c0ea8ffb62e0490ebed2faa55ad
# ...
#   Created wheel for regex: filename=regex-2019.12.20-cp27-cp27mu-linux_x86_64.whl size=347015 sha256=47e990b5536ce415288f9e2be7968628a4b5980fe85fea387a21588f96e53d03
#   Stored in directory: /root/.cache/pip/wheels/98/16/eb/136427a471a706ea4847904c4b37c27a21bc3c90763092b67c
# Successfully built PyInquirer regex
# ERROR: google-colab 1.0.0 has requirement six~=1.12.0, but you'll have six 1.11.0 which is incompatible.
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-38acfea4-2f26-457c-a565-382038060fbc" name="files[]" multiple disabled />
#      <output id="result-38acfea4-2f26-457c-a565-382038060fbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving model.h5 to model.h5
# ...

# %%
# !tensorflowjs_converter --quantization_bytes 1 --input_format=keras model.h5 modelq/
